# %%
### 1 Data "Avalaibility of a dat in one store"

# %%
# Path of the file to read
Inventory_filepath = "../Week11/Inventory.csv"

# Read the file into a variable spotify_data
Inventory_data = pd.read_csv(Inventory_filepath)

# %%
# Print the first 5 rows of the data
Inventory_data.head()
# Out:
#    ProductId  StoreId               StoreName                Address  \
# 0          1    85123         National Stores     9 Springview Point
# 1          2    71053           Family Dollar    5434 Daystar Circle
# 2          3    84406     BJ's Wholesale Club         3 Darwin Drive
# 3          4    84029     Ocean State Job Lot       684 Bunting Lane
# 4          5    37444  Ollie's Bargain Outlet  50162 John Wall Drive
#
#       neighborhood  QuantityAvailable
# 0      Bolton Hill                 11
# 1        Ashburton                  1
# 2     Morrell Park                 11
# 3      Fells Point                  1
# 4  Charles Village                  3

# %%
# Print the last five rows of the data
Inventory_data.tail()
# Out:
#      ProductId  StoreId                StoreName                  Address  \
# 995        996    21777                  Walmart          7 Roxbury Place
# 996        997    10002                T.J. Maxx        9476 Morrow Trail
# 997        998    22745  Burlington Coat Factory  3029 Hollow Ridge Place
# 998        999    21755          Tuesday Morning           496 Dapin Hill
# 999       1000    22633                 Big Lots          99 Granby Place
#
#             neighborhood  QuantityAvailable
# 995     Sabina-Mattfeldt                  3
# 996  Seton Business Park                 12
# 997                Upton                  6
# 998        Belair-Edison                  6
# 999             Brooklyn                  2

# %%
#Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Availability of the item in each store")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=Inventory_data.index, y=Inventory_data['StoreName'])

# Add label for vertical axis
plt.ylabel("StoreName")
# Out:
# Text(0, 0.5, 'StoreName')

# %%
## Working with data 'Cars in India'

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
Cars_India_dataset_filepath = "../Week11/candy.csv"
# Read the file into a variable fifa_data
Cars_India_dataset = pd.read_csv(Cars_India_dataset_filepath)
Cars_India_dataset
# Out:
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
#Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Cars in India")

# Bar chart showing if each compititor has the fruity type or not
sns.barplot(x=Cars_India_dataset.index, y=Cars_India_dataset['fruity'])

# Add label for vertical axis
plt.ylabel("Type")
# Out:
# Text(0, 0.5, 'Type')

# %%
##2
